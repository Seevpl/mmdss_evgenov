# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
accuracy = 0.001
a = -1
b = 2
step = 0.01
y_param = 3

# %% [markdown]
# Создадим функцию, выдающую значение функции Леви N.13 при заданных x, y.

# %%
# Функция для определения локального мимнимума
def f(x, y = y_param):
    res = np.sin(3 * math.pi * x) ** 2 + (x - 1) ** 2 * (1 + np.sin(3 * math.pi * y) ** 2)
    return res + (y - 1) ** 2 * (1 + np.sin(2 * math.pi * y) ** 2)

# %% [markdown]
# Приступим к реализации метода

# %%
#Зададим область определения и область допустимых значений

x = np.arange(a, b, step)
z = f(x)

plt.figure(figsize=(12,6))
plt.title('График функции')
plt.plot(x, z, label = r'$sin^2(3πx)$ + $(x-1)^2(1+sin^2(3πy))$ + $(y-1)^2(1+sin^2(2πy))$', linewidth = 2, color = 'red')
plt.xlabel('X')
plt.ylabel('f(x, y)')
plt.grid()
plt.legend(loc = 'best')
plt.show();

# %%
#Найдём константу Липшица
def find_lipschitz_const(X, func):
    u = X[0]
    lip_const = -1
    w_u = func(u)
    for i in X[1:]:
        v = i
        w_v = func(v)
        temp_lip_const = abs(w_u - w_v) / abs(u - v)
        lip_const = max(lip_const, temp_lip_const)
        u = v
        w_u = w_v
    return lip_const

# %%
lip_const = find_lipschitz_const(x, f)
lip_const
# Out:
# 12.879065729286133

# %%
# Код для получения ломанной
def get_broken_line(x, k, lip_const, func):
    g = func(k) - lip_const * np.abs(x-k)
    return g

# Код для метода Пиявского
def piyavski_method(function, a, b, accuracy):
    x = np.arange(a, b, 0.01)
    lip_const = find_lipschitz_const(x, function)
    g_0 = get_broken_line(x, a, lip_const, function)
    g_1 = get_broken_line(x, b, lip_const, function)
    bl = np.maximum(g_0, g_1)
    x_min = x[np.nanargmin(bl)]

    for i in range(1000):
        x_min = x[np.nanargmin(bl)]
        y_min = min(bl)
        f_min = function(x_min)
        if accuracy >= abs(f_min-y_min):
            print(f'Минимум найден за: {i} итераций')
            break

        g = get_broken_line(x, x_min, lip_const, function)
        bl = np.maximum(g, bl)
    piyavski_method_visual()
    return bl, x_min, y_min

# Код для визуализации метода
def piyavski_method_visual():
    plt.figure(figsize=(18,10))
    plt.title('Нахождение локального минимума методом ломаных\n', fontsize = 24)
    plt.plot(x, broken_line, label =r'Ломанная функция', linewidth=1, color= 'blue')
    plt.plot(x, z, label=r'$2x$ + $cos(πx)$ + $sin(πx)$', linewidth=2, color='green', alpha=0.4)
    plt.scatter(x_min, y_min, marker='x',color = 'red')
    plt.annotate(f"минимум миноранты ({round(x_min, 2)},{round(y_min, 2)})", (x_min,y_min),
            xytext=(x_min-0.1, y_min+2),
            arrowprops=dict(arrowstyle='->'))
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.grid()
    plt.legend(loc='best')
    plt.show();

# %%
# %%time
broken_line, x_min, y_min = piyavski_method(f, a, b, accuracy)
# Out:
# Минимум найден за: 41 итераций
# CPU times: total: 281 ms
# Wall time: 287 ms

# %%
x_min, y_min
# Out:
# (1.0000000000000018, 4.0)

# %% [markdown]
# ![d](excel.png)
